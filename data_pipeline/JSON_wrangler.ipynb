# %% [markdown]
# ## Imports and initial look at data

# %%
from pprint import pprint
import pandas as pd
import os
import jsonlines
pd.set_option('display.max_columns', None)
import json
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Extract JSONL into dataframes
# Separate df for product page, reviews page, and bestsellers page

# %%
jsonl_files = [
    'dataset_Amazon-crawler_2023-06-16_09-05-55-623.jsonl', 
    'dataset_Amazon-crawler_2023-06-16_10-33-19-259.jsonl', 
    'dataset_Amazon-crawler_2023-06-16_10-22-09-925.jsonl', 
    'dataset_amazon-bestsellers_2023-06-16_13-09-24-209.jsonl', 
    'dataset_amazon-bestsellers_2023-06-16_13-03-46-148.jsonl', 
    'dataset_amazon-reviews-scraper_2023-06-16_12-41-00-735.jsonl', 
    'dataset_amazon-reviews-scraper_2023-06-16_09-35-54-585.jsonl', 
    'dataset_amazon-reviews-scraper-task_2023-06-16_11-03-38-627.jsonl'
]

crawler_data = []
bestsellers_data = []
reviews_data = []

for jsonl_file in jsonl_files:
    if jsonl_file.endswith('.jsonl'):
        
        with open(f'/amazon_data/{jsonl_file}') as file:
            print(jsonl_file, len(file.readlines()))
        with open(f'/amazon_data/{jsonl_file}') as file:
            if 'crawler' in jsonl_file:
                for line in file:
                    crawler_data.append(json.loads(line))
            elif 'bestsellers' in jsonl_file:
                for line in file:
                    bestsellers_data.append(json.loads(line))
            elif 'reviews' in jsonl_file:
                for line in file:
                    reviews_data.append(json.loads(line))

crawler_df = pd.DataFrame(crawler_data)
bestsellers_df = pd.DataFrame(bestsellers_data)
reviews_df = pd.DataFrame(reviews_data)

# %% [markdown]
# ### Get initial info on raw JSONL data

# %%
for dftype, df in zip(['crawler', 'bestsellers', 'reviews'],
              [crawler_df, bestsellers_df, reviews_df]):
    print(dftype)
    print(f'shape: {df.shape}')
    print(f'firstcol: {df.columns[0]}')
    print(f'lastcol: {df.columns[-1]}')
    
    null_cols = df.columns[df.isnull().all()].tolist()
    print(f'null_cols: {null_cols} (dropping)')
    df.drop(null_cols, axis=1, inplace=True)

    null_counts = df.isnull().sum()
    null_counts_df = pd.DataFrame(null_counts, columns=['Null Count'])
    null_counts_df['Null Percent'] = null_counts_df['Null Count'] / df.shape[0]
    print('Cols with nulls:')
    display(null_counts_df[null_counts_df['Null Count'] > 0])

    list_cols = [col for col in df.columns if isinstance(df[col].iloc[0], list) or isinstance(df[col].iloc[0], dict)]
    print(f'cols containing dict or list: {list_cols}')

    print(f'{dftype}_df:')
    display(df.head(3))


    df.to_excel(f'/amazon_data/{dftype}_agg_df.xlsx')
# Out:
# crawler
# shape: (2157, 32)
# firstcol: title
# lastcol: locationText
# null_cols: ['shippingPrice', 'priceVariants'] (dropping)
# Cols with nulls:
#                    Null Count  Null Percent
# price                      87      0.040334
# listPrice                1326      0.614743
# stars                     252      0.116829
# reviewsCount              252      0.116829
# answeredQuestions         626      0.290218
# description               705      0.326843
# reviewsLink               353      0.163653
# delivery                   97      0.044970
# fastestDelivery           483      0.223922
# returnPolicy             2147      0.995364
# support                  2150      0.996755
# seller                     91      0.042188
# bestsellerRanks          2154      0.998609
# saleSummary              1772      0.821511
# cols containing dict or list: ['price', 'listPrice', 'starsBreakdown', 'features', 'attributes', 'variantAsins', 'variantAttributes', 'manufacturerAttributes', 'seller']
# crawler_df:
#                                                title  \
# 0  Mini PC, 11th Intel i7-1165G7(up to 4.7GHz) Th...
# 1  GEEKOM Mini IT11 Mini PC, 1TB Intel i7-11390H ...
# 2  Dell Precision Tower 3420 SFF Intel Core i7-77...
#
#                                     url        asin  inStock  \
# 0  https://www.amazon.com/dp/B0BNM4WLBJ  B0BNM4WLBJ     True
# 1  https://www.amazon.com/dp/B0BQVM2XL6  B0BQVM2XL6     True
# 2  https://www.amazon.com/dp/B0958ZM66D  B0958ZM66D     True
#
#                           inStockText           brand  \
# 0  Only 19 left in stock - order soon          sinbun
# 1              In Stock     In Stock.          GEEKOM
# 2                           In Stock.  Amazon Renewed
#
#                                 price                           listPrice  \
# 0     {'value': 529, 'currency': '$'}     {'value': 579, 'currency': '$'}
# 1  {'value': 599.99, 'currency': '$'}  {'value': 749.99, 'currency': '$'}
# 2  {'value': 533.99, 'currency': '$'}                                None
#
#    stars                                     starsBreakdown  reviewsCount  \
# 0    4.4  {'5star': 0.7, '4star': 0.18, '3star': 0, '2st...          14.0
# 1    4.7  {'5star': 0.8, '4star': 0.15, '3star': 0, '2st...          54.0
# 2    NaN  {'5star': 0, '4star': 0, '3star': 0, '2star': ...           NaN
#
#    answeredQuestions                                        breadCrumbs  \
# 0               11.0  Electronics › Computers & Accessories › Comput...
# 1               35.0  Electronics › Computers & Accessories › Comput...
# 2                NaN  Electronics › Computers & Accessories › Comput...
#
#                                       thumbnailImage  \
# 0  https://m.media-amazon.com/images/I/61oop4yoyF...
# 1  https://m.media-amazon.com/images/I/51W6MBfVCT...
# 2  https://m.media-amazon.com/images/I/616n0bPSxb...
#
#                                          description  \
# 0                                               None
# 1                                               None
# 2  Boost up your computing experience with Refurb...
#
#                                             features  \
# 0  [【11th Intel Core i7 processor】11th i7 mini PC...
# 1  [[A Mini PC with An Upgraded Processor] GEEKOM...
# 2  [This Certified Refurbished product is tested ...
#
#                                           attributes  \
# 0  [{'key': 'Processor', 'value': '4.7 GHz core_i...
# 1  [{'key': 'Standing screen display size', 'valu...
# 2  [{'key': 'Processor', 'value': '3.6 GHz core_i...
#
#                            variantAsins  \
# 0  [B0BNM4WLBJ, B0B8D2D7RN, B0BQ2BBRDV]
# 1              [B0BQVM2XL6, B0BQWCQ7ZY]
# 2                                    []
#
#                                          reviewsLink  hasReviews  \
# 0  /i7-1165G7-Thunderbolt-Desktop-Computer-Comput...        True
# 1  /GEEKOM-Mini-IT11-i7-11390H-Computer/product-r...        True
# 2                                                NaN       False
#
#             delivery   fastestDelivery returnPolicy support  \
# 0  Wednesday, May 17  Tomorrow, May 12         None    None
# 1  Wednesday, May 17  Tomorrow, May 12         None    None
# 2        May 18 - 25       May 15 - 18         None    None
#
#                                   variantAttributes  \
# 0  [{'key': 'Size', 'value': 'I7-1165G7 16G/512G'}]
# 1   [{'key': 'Size', 'value': 'i711390H-32GB+1TB'}]
# 2                                                []
#
#                               manufacturerAttributes  \
# 0  [{'key': 'Thunderbolt 4.0 Type-C Port', 'value...
# 1                                                 []
# 2                                                 []
#
#                                               seller bestsellerRanks  \
# 0  {'name': 'Sinbun Direct', 'id': 'A26EVMAO82NEO...            None
# 1  {'name': 'GEEKOM Brand Store', 'id': 'A3FHF27Z...            None
# 2  {'name': 'Joy Systems Inc', 'id': 'APEGUV39VCX...            None
#
#                saleSummary         locationText
# 0  Save $50.00 with coupon  Select your address
# 1                     None  Select your address
# 2                     None  Select your address
# bestsellers
# shape: (200, 37)
# firstcol: position
# lastcol: locationText
# null_cols: ['shippingPrice', 'priceVariants', 'bestsellerRanks'] (dropping)
# Cols with nulls:
#                    Null Count  Null Percent
# listPrice                  79         0.395
# stars                       1         0.005
# reviewsCount                1         0.005
# answeredQuestions           5         0.025
# description                90         0.450
# reviewsLink                 2         0.010
# delivery                    8         0.040
# fastestDelivery            50         0.250
# returnPolicy              197         0.985
# support                   197         0.985
# seller                      5         0.025
# cols containing dict or list: ['listPrice', 'starsBreakdown', 'features', 'attributes', 'variantAsins', 'variantAttributes', 'manufacturerAttributes', 'seller']
# bestsellers_df:
#    position                                     category  \
# 0        30  Amazon Best Sellers: Best Desktop Computers
# 1        27  Amazon Best Sellers: Best Desktop Computers
# 2        29  Amazon Best Sellers: Best Desktop Computers
#
#                                          categoryUrl  \
# 0  https://www.amazon.com/Best-Sellers-Computers-...
# 1  https://www.amazon.com/Best-Sellers-Computers-...
# 2  https://www.amazon.com/Best-Sellers-Computers-...
#
#                                                 name   price currency  \
# 0  Beelink Mini PC, Intel 12th Gen Alder Lake- N9...  159.00        $
# 1  Mini PC Windows 11 Pro, KAMRUI AK1 PRO 12GB RA...  199.99        $
# 2  HP 2022 Newest All-in-One Desktop, 21.5" FHD D...  589.00        $
#
#    numberOfOffers                                   url  \
# 0               1  https://www.amazon.com/dp/B0BVLPCDVW
# 1               1  https://www.amazon.com/dp/B099KSJN8P
# 2               1  https://www.amazon.com/dp/B0B6523VBD
#
#                                            thumbnail  \
# 0  https://images-na.ssl-images-amazon.com/images...
# 1  https://images-na.ssl-images-amazon.com/images...
# 2  https://images-na.ssl-images-amazon.com/images...
#
#                                                title        asin  inStock  \
# 0  Beelink Mini PC, Intel 12th Gen Alder Lake- N9...  B0BVLPCDVW     True
# 1  Mini PC Windows 11 Pro, KAMRUI AK1 PRO 12GB RA...  B099KSJN8P     True
# 2  HP 2022 Newest All-in-One Desktop, 21.5" FHD D...  B0B6523VBD     True
#
#                          inStockText    brand  \
# 0                           In Stock  Beelink
# 1             In Stock     In Stock.   KAMRUI
# 2  Only 3 left in stock - order soon       HP
#
#                             listPrice  stars  \
# 0     {'value': 199, 'currency': '$'}    4.6
# 1  {'value': 259.99, 'currency': '$'}    4.4
# 2                                None    4.4
#
#                                       starsBreakdown  reviewsCount  \
# 0  {'5star': 0.79, '4star': 0.14, '3star': 0.03, ...         115.0
# 1  {'5star': 0.68, '4star': 0.17, '3star': 0.05, ...         876.0
# 2  {'5star': 0.69, '4star': 0.17, '3star': 0.04, ...         174.0
#
#    answeredQuestions                                        breadCrumbs  \
# 0               19.0  Electronics › Computers & Accessories › Comput...
# 1              156.0  Electronics › Computers & Accessories › Comput...
# 2               28.0  Electronics › Computers & Accessories › Comput...
#
#                                       thumbnailImage description  \
# 0  https://m.media-amazon.com/images/I/71yonCCmlv...        None
# 1  https://m.media-amazon.com/images/I/71LgGofvm1...        None
# 2  https://m.media-amazon.com/images/I/91-CdWQGWA...        None
#
#                                             features  \
# 0  [✔️12th Intel Alder Lake-N95 - Beelink Mini S1...
# 1  [[Small but Powerful]-Mini PC about 5.04 x 5.0...
# 2  [【High Speed RAM And Enormous Space】16GB DDR4 ...
#
#                                           attributes  \
# 0  [{'key': 'Processor', 'value': '3.4 GHz none'}...
# 1  [{'key': 'Standing screen display size', 'valu...
# 2  [{'key': 'Standing screen display size', 'valu...
#
#                                        variantAsins  \
# 0  [B0BVLPCDVW, B0BVLS7ZHP, B09ZLBDVZD, B09ZLDBC8X]
# 1                                                []
# 2                                                []
#
#                                          reviewsLink           delivery  \
# 0  /Beelink-Desktop-Computer-Support-Ethernet/pro...  Wednesday, May 17
# 1  /Computer-Celeron-J3455-Processor-2-5-inch/pro...  Wednesday, May 17
# 2  /HP-Desktop-Display-Processor-Keyboard/product...        May 15 - 17
#
#     fastestDelivery returnPolicy support  \
# 0  Tomorrow, May 12         None    None
# 1  Tomorrow, May 12         None    None
# 2              None         None    None
#
#                            variantAttributes manufacturerAttributes  \
# 0  [{'key': 'Size', 'value': 'N95 8G+256G'}]                     []
# 1                                         []                     []
# 2                                         []                     []
#
#                                               seller         locationText
# 0  {'name': 'Beelink US', 'id': 'A2RITUENS753LH',...  Select your address
# 1  {'name': 'KAMRUI-US', 'id': 'A3R3T09IX9ERXX', ...  Select your address
# 2  {'name': 'Hott Tech Geek', 'id': 'A3TYVCQOBOEC...  Select your address
# reviews
# shape: (23950, 14)
# firstcol: productAsin
# lastcol: position
# null_cols: [] (dropping)
# Cols with nulls:
#              Null Count  Null Percent
# reviewUrl           543      0.022672
# countryCode       11874      0.495783
# cols containing dict or list: ['reviewImages']
# reviews_df:
#   productAsin  ratingScore           reviewTitle  \
# 0  B0BYJWRSC1            4        Painful Laptop
# 1  B0BYJWRSC1            5  Has all the features
# 2  B0BYJWRSC1            5         Great Service
#
#                                            reviewUrl reviewReaction  \
# 0  https://www.amazon.com/gp/customer-reviews/R6N...
# 1  https://www.amazon.com/gp/customer-reviews/R39...
# 2  https://www.amazon.com/gp/customer-reviews/R3V...
#
#                                           reviewedIn        date  \
# 0    Reviewed in the United States 🇺🇸 on May 6, 2023  2023-05-06
# 1  Reviewed in the United States 🇺🇸 on April 20, ...  2023-04-20
# 2  Reviewed in the United States 🇺🇸 on April 26, ...  2023-04-26
#
#          country countryCode  \
# 0  United States          🇺🇸
# 1  United States          🇺🇸
# 2  United States          🇺🇸
#
#                                    reviewDescription  isVerified  \
# 0  This is a fast and elegant looking Windows 11 ...        True
# 1  This laptop is fast! 64 mb of ram really crank...        True
# 2     Fast delivery and product exactly as described        True
#
#                                      variant reviewImages  position
# 0  Capacity: 64GB RAM|2TB SSDStyle: Win11Pro           []         1
# 1  Capacity: 64GB RAM|2TB SSDStyle: Win11Pro           []         2
# 2  Capacity: 64GB RAM|2TB SSDStyle: Win11Pro           []         3

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Drop irrelevant columns

# %%
crawler_df.drop(columns=[
                         'inStock',
                         'inStockText',
                         'listPrice',
                         'starsBreakdown',
                         'answeredQuestions',
                         'delivery',
                         'fastestDelivery',
                         'returnPolicy',
                         'support',
                         'seller',
                         'bestsellerRanks',
                         'saleSummary',
                         'locationText'],
                inplace=True)
crawler_df.drop_duplicates(subset=['asin'], keep='first', inplace=True)

# %%
bestsellers_df.drop(columns=[
                            'inStock',
                            'inStockText',
                            'listPrice',
                            'starsBreakdown',
                            'answeredQuestions',
                            'delivery',
                            'fastestDelivery',
                            'returnPolicy',
                            'support',
                            'seller',
                            'locationText'],
                    inplace=True)

# %%
reviews_df.drop(columns=[
    'isVerified',
    'variant',
    'reviewImages',
    'position'],
    inplace=True)

# %% [markdown]
# ### Remove miscategorized items and map AMZN section string to Category & Sub-Category fields

# %%
crawler_df = crawler_df[~crawler_df['breadCrumbs'].str.contains('Camera')]
category_map = {         'Electronics › Computers & Accessories › Computers & Tablets › Desktops › Minis' : 'Desktops',
                     'Electronics › Computers & Accessories › Computers & Tablets › Desktops › Towers' : 'Desktops',
                     'Electronics › Computers & Accessories › Computers & Tablets › Desktops › All-in-Ones' : 'Desktops',
                     'Electronics › Computers & Accessories › Computers & Tablets › Laptops › Traditional Laptops' : 'Laptops',
                     'Electronics › Computers & Accessories › Computers & Tablets › Laptops › 2 in 1 Laptops' : 'Laptops',
                     'Electronics › Computers & Accessories › Computers & Tablets › Laptops' : 'Laptops'}

subcategory_map = {         'Electronics › Computers & Accessories › Computers & Tablets › Desktops › Minis' : 'Minis',
                     'Electronics › Computers & Accessories › Computers & Tablets › Desktops › Towers' : 'Towers',
                     'Electronics › Computers & Accessories › Computers & Tablets › Desktops › All-in-Ones' : 'All-in-Ones',
                     'Electronics › Computers & Accessories › Computers & Tablets › Laptops › Traditional Laptops' : 'Traditional',
                     'Electronics › Computers & Accessories › Computers & Tablets › Laptops › 2 in 1 Laptops' : '2-in-1',
                     'Electronics › Computers & Accessories › Computers & Tablets › Laptops' : 'Traditional'}

crawler_df['category'] = crawler_df['breadCrumbs'].map(category_map)
crawler_df['sub-category'] = crawler_df['breadCrumbs'].map(subcategory_map)

crawler_df.head()
# Out:
#                                                title  \
# 0  Mini PC, 11th Intel i7-1165G7(up to 4.7GHz) Th...
# 1  GEEKOM Mini IT11 Mini PC, 1TB Intel i7-11390H ...
# 2  Dell Precision Tower 3420 SFF Intel Core i7-77...
# 3  AVGPC Q-Box Mini Series PC - AMD Ryzen 5 5600G...
# 4  Apple 2023 Mac Mini Desktop Computer M2 chip w...
#
#                                     url        asin           brand  \
# 0  https://www.amazon.com/dp/B0BNM4WLBJ  B0BNM4WLBJ          sinbun
# 1  https://www.amazon.com/dp/B0BQVM2XL6  B0BQVM2XL6          GEEKOM
# 2  https://www.amazon.com/dp/B0958ZM66D  B0958ZM66D  Amazon Renewed
# 3  https://www.amazon.com/dp/B099CHVFJJ  B099CHVFJJ           AVGPC
# 4  https://www.amazon.com/dp/B0BSHGHGXR  B0BSHGHGXR           Apple
#
#                                 price  stars  reviewsCount  \
# 0     {'value': 529, 'currency': '$'}    4.4          14.0
# 1  {'value': 599.99, 'currency': '$'}    4.7          54.0
# 2  {'value': 533.99, 'currency': '$'}    NaN           NaN
# 3     {'value': 549, 'currency': '$'}    3.9          23.0
# 4     {'value': 559, 'currency': '$'}    4.6         184.0
#
#                                          breadCrumbs  \
# 0  Electronics › Computers & Accessories › Comput...
# 1  Electronics › Computers & Accessories › Comput...
# 2  Electronics › Computers & Accessories › Comput...
# 3  Electronics › Computers & Accessories › Comput...
# 4
#
#                                       thumbnailImage  \
# 0  https://m.media-amazon.com/images/I/61oop4yoyF...
# 1  https://m.media-amazon.com/images/I/51W6MBfVCT...
# 2  https://m.media-amazon.com/images/I/616n0bPSxb...
# 3  https://m.media-amazon.com/images/I/61LAnQI-iH...
# 4  https://m.media-amazon.com/images/I/61La8PAa42...
#
#                                          description  \
# 0                                               None
# 1                                               None
# 2  Boost up your computing experience with Refurb...
# 3  Product images used on this page are for illus...
# 4                                               None
#
#                                             features  \
# 0  [【11th Intel Core i7 processor】11th i7 mini PC...
# 1  [[A Mini PC with An Upgraded Processor] GEEKOM...
# 2  [This Certified Refurbished product is tested ...
# 3  [AMD Ryzen 5 5600G 3.9Ghz with Integrated AMD ...
# 4  [SUPERCHARGED BY M2 — Get more done faster wit...
#
#                                           attributes  \
# 0  [{'key': 'Processor', 'value': '4.7 GHz core_i...
# 1  [{'key': 'Standing screen display size', 'valu...
# 2  [{'key': 'Processor', 'value': '3.6 GHz core_i...
# 3  [{'key': 'Processor', 'value': '4.8 GHz ryzen_...
# 4                                                 []
#
#                                         variantAsins  \
# 0               [B0BNM4WLBJ, B0B8D2D7RN, B0BQ2BBRDV]
# 1                           [B0BQVM2XL6, B0BQWCQ7ZY]
# 2                                                 []
# 3  [B099CHVFJJ, B09X2JCX8Z, B0BGYRWRH7, B099CSM7L...
# 4   [B0BSHGHGXR, B0BSHFS6XX, B0BSHGHGXR, B0BSHGTPMV]
#
#                                          reviewsLink  hasReviews  \
# 0  /i7-1165G7-Thunderbolt-Desktop-Computer-Comput...        True
# 1  /GEEKOM-Mini-IT11-i7-11390H-Computer/product-r...        True
# 2                                                NaN       False
# 3  /AVGPC-Q-Box-Gaming-PC-Q-Box_7/product-reviews...        True
# 4  /Apple-Desktop-Computer-10%E2%80%91core-Ethern...        True
#
#                                    variantAttributes  \
# 0   [{'key': 'Size', 'value': 'I7-1165G7 16G/512G'}]
# 1    [{'key': 'Size', 'value': 'i711390H-32GB+1TB'}]
# 2                                                 []
# 3        [{'key': 'Style', 'value': 'Mini_B_5700G'}]
# 4  [{'key': 'Style', 'value': 'Apple M2 Chip'}, {...
#
#                               manufacturerAttributes  category sub-category
# 0  [{'key': 'Thunderbolt 4.0 Type-C Port', 'value...  Desktops        Minis
# 1                                                 []  Desktops        Minis
# 2                                                 []  Desktops       Towers
# 3                                                 []  Desktops       Towers
# 4                                                 []       NaN          NaN

# %% [markdown]
# # Fill in missing Category data for Mac products
# (for some reason 'breadCrumbs' and 'attributes' were not populated for some Apple products)

# %%
# where breadCrumbs is null and 'brand'=='Apple', set 'category' to Desktops the string 'desktop' or 'mini' appears in the title, otherwise set it to Laptops
crawler_df.loc[(crawler_df['category'].isnull()) & (crawler_df['brand']=='Apple') & (crawler_df['title'].str.lower().str.contains('desktop') | crawler_df['title'].str.lower().str.contains('mini')), 'category'] = 'Desktops'
crawler_df.loc[(crawler_df['sub-category'].isnull()) & (crawler_df['brand']=='Apple') & (crawler_df['title'].str.lower().str.contains('desktop') | crawler_df['title'].str.lower().str.contains('mini')), 'sub-category'] = 'Minis'
crawler_df.loc[(crawler_df['category'].isnull()) & (crawler_df['title'].str.lower().str.contains('laptop')  | crawler_df['title'].str.lower().str.contains('macbook')), 'category'] = 'Laptops'
crawler_df.loc[(crawler_df['sub-category'].isnull()) & (crawler_df['title'].str.lower().str.contains('laptop')  | crawler_df['title'].str.lower().str.contains('macbook')), 'sub-category'] = 'Traditional'

# drop breadcrumbs -- extracted to category
crawler_df.drop(columns=['breadCrumbs'], inplace=True)

crawler_df.head()
# Out:
#                                                title  \
# 0  Mini PC, 11th Intel i7-1165G7(up to 4.7GHz) Th...
# 1  GEEKOM Mini IT11 Mini PC, 1TB Intel i7-11390H ...
# 3  AVGPC Q-Box Mini Series PC - AMD Ryzen 5 5600G...
# 4  Apple 2023 Mac Mini Desktop Computer M2 chip w...
# 6  HP Chromebase 21.5" All-in-One Desktop, Intel ...
#
#                                     url        asin   brand  \
# 0  https://www.amazon.com/dp/B0BNM4WLBJ  B0BNM4WLBJ  sinbun
# 1  https://www.amazon.com/dp/B0BQVM2XL6  B0BQVM2XL6  GEEKOM
# 3  https://www.amazon.com/dp/B099CHVFJJ  B099CHVFJJ   AVGPC
# 4  https://www.amazon.com/dp/B0BSHGHGXR  B0BSHGHGXR   Apple
# 6  https://www.amazon.com/dp/B099P4T81H  B099P4T81H      HP
#
#                                 price  stars  reviewsCount  \
# 0     {'value': 529, 'currency': '$'}    4.4          14.0
# 1  {'value': 599.99, 'currency': '$'}    4.7          54.0
# 3     {'value': 549, 'currency': '$'}    3.9          23.0
# 4     {'value': 559, 'currency': '$'}    4.6         184.0
# 6     {'value': 545, 'currency': '$'}    4.3         264.0
#
#                                          breadCrumbs  \
# 0  Electronics › Computers & Accessories › Comput...
# 1  Electronics › Computers & Accessories › Comput...
# 3  Electronics › Computers & Accessories › Comput...
# 4
# 6  Electronics › Computers & Accessories › Comput...
#
#                                       thumbnailImage  \
# 0  https://m.media-amazon.com/images/I/61oop4yoyF...
# 1  https://m.media-amazon.com/images/I/51W6MBfVCT...
# 3  https://m.media-amazon.com/images/I/61LAnQI-iH...
# 4  https://m.media-amazon.com/images/I/61La8PAa42...
# 6  https://m.media-amazon.com/images/I/81w3miL-DH...
#
#                                          description  \
# 0                                               None
# 1                                               None
# 3  Product images used on this page are for illus...
# 4                                               None
# 6  Change your perspective on home PCs with the H...
#
#                                             features  \
# 0  [【11th Intel Core i7 processor】11th i7 mini PC...
# 1  [[A Mini PC with An Upgraded Processor] GEEKOM...
# 3  [AMD Ryzen 5 5600G 3.9Ghz with Integrated AMD ...
# 4  [SUPERCHARGED BY M2 — Get more done faster wit...
# 6  [FLEXIBLE FAMILY FUN – Designed to live at the...
#
#                                           attributes  \
# 0  [{'key': 'Processor', 'value': '4.7 GHz core_i...
# 1  [{'key': 'Standing screen display size', 'valu...
# 3  [{'key': 'Processor', 'value': '4.8 GHz ryzen_...
# 4                                                 []
# 6  [{'key': 'Standing screen display size', 'valu...
#
#                                         variantAsins  \
# 0               [B0BNM4WLBJ, B0B8D2D7RN, B0BQ2BBRDV]
# 1                           [B0BQVM2XL6, B0BQWCQ7ZY]
# 3  [B099CHVFJJ, B09X2JCX8Z, B0BGYRWRH7, B099CSM7L...
# 4   [B0BSHGHGXR, B0BSHFS6XX, B0BSHGHGXR, B0BSHGTPMV]
# 6                                                 []
#
#                                          reviewsLink  hasReviews  \
# 0  /i7-1165G7-Thunderbolt-Desktop-Computer-Comput...        True
# 1  /GEEKOM-Mini-IT11-i7-11390H-Computer/product-r...        True
# 3  /AVGPC-Q-Box-Gaming-PC-Q-Box_7/product-reviews...        True
# 4  /Apple-Desktop-Computer-10%E2%80%91core-Ethern...        True
# 6  /HP-Chromebase-Processor-Touchscreen-22-aa0022...        True
#
#                                    variantAttributes  \
# 0   [{'key': 'Size', 'value': 'I7-1165G7 16G/512G'}]
# 1    [{'key': 'Size', 'value': 'i711390H-32GB+1TB'}]
# 3        [{'key': 'Style', 'value': 'Mini_B_5700G'}]
# 4  [{'key': 'Style', 'value': 'Apple M2 Chip'}, {...
# 6                                                 []
#
#                               manufacturerAttributes  category sub-category
# 0  [{'key': 'Thunderbolt 4.0 Type-C Port', 'value...  Desktops        Minis
# 1                                                 []  Desktops        Minis
# 3                                                 []  Desktops       Towers
# 4                                                 []  Desktops        Minis
# 6                                                 []  Desktops  All-in-Ones

# %%
# extract 'value' from the dict stored in 'price'
crawler_df['price'] = crawler_df['price'].apply(lambda x: x['value'] if isinstance(x, dict) else x)

# drop rows missing px
crawler_df = crawler_df[~crawler_df.price.isnull()]

crawler_df.head()
# Out:
#                                                title  \
# 0  Mini PC, 11th Intel i7-1165G7(up to 4.7GHz) Th...
# 1  GEEKOM Mini IT11 Mini PC, 1TB Intel i7-11390H ...
# 3  AVGPC Q-Box Mini Series PC - AMD Ryzen 5 5600G...
# 4  Apple 2023 Mac Mini Desktop Computer M2 chip w...
# 6  HP Chromebase 21.5" All-in-One Desktop, Intel ...
#
#                                     url        asin   brand   price  stars  \
# 0  https://www.amazon.com/dp/B0BNM4WLBJ  B0BNM4WLBJ  sinbun  529.00    4.4
# 1  https://www.amazon.com/dp/B0BQVM2XL6  B0BQVM2XL6  GEEKOM  599.99    4.7
# 3  https://www.amazon.com/dp/B099CHVFJJ  B099CHVFJJ   AVGPC  549.00    3.9
# 4  https://www.amazon.com/dp/B0BSHGHGXR  B0BSHGHGXR   Apple  559.00    4.6
# 6  https://www.amazon.com/dp/B099P4T81H  B099P4T81H      HP  545.00    4.3
#
#    reviewsCount                                     thumbnailImage  \
# 0          14.0  https://m.media-amazon.com/images/I/61oop4yoyF...
# 1          54.0  https://m.media-amazon.com/images/I/51W6MBfVCT...
# 3          23.0  https://m.media-amazon.com/images/I/61LAnQI-iH...
# 4         184.0  https://m.media-amazon.com/images/I/61La8PAa42...
# 6         264.0  https://m.media-amazon.com/images/I/81w3miL-DH...
#
#                                          description  \
# 0                                               None
# 1                                               None
# 3  Product images used on this page are for illus...
# 4                                               None
# 6  Change your perspective on home PCs with the H...
#
#                                             features  \
# 0  [【11th Intel Core i7 processor】11th i7 mini PC...
# 1  [[A Mini PC with An Upgraded Processor] GEEKOM...
# 3  [AMD Ryzen 5 5600G 3.9Ghz with Integrated AMD ...
# 4  [SUPERCHARGED BY M2 — Get more done faster wit...
# 6  [FLEXIBLE FAMILY FUN – Designed to live at the...
#
#                                           attributes  \
# 0  [{'key': 'Processor', 'value': '4.7 GHz core_i...
# 1  [{'key': 'Standing screen display size', 'valu...
# 3  [{'key': 'Processor', 'value': '4.8 GHz ryzen_...
# 4                                                 []
# 6  [{'key': 'Standing screen display size', 'valu...
#
#                                         variantAsins  \
# 0               [B0BNM4WLBJ, B0B8D2D7RN, B0BQ2BBRDV]
# 1                           [B0BQVM2XL6, B0BQWCQ7ZY]
# 3  [B099CHVFJJ, B09X2JCX8Z, B0BGYRWRH7, B099CSM7L...
# 4   [B0BSHGHGXR, B0BSHFS6XX, B0BSHGHGXR, B0BSHGTPMV]
# 6                                                 []
#
#                                          reviewsLink  hasReviews  \
# 0  /i7-1165G7-Thunderbolt-Desktop-Computer-Comput...        True
# 1  /GEEKOM-Mini-IT11-i7-11390H-Computer/product-r...        True
# 3  /AVGPC-Q-Box-Gaming-PC-Q-Box_7/product-reviews...        True
# 4  /Apple-Desktop-Computer-10%E2%80%91core-Ethern...        True
# 6  /HP-Chromebase-Processor-Touchscreen-22-aa0022...        True
#
#                                    variantAttributes  \
# 0   [{'key': 'Size', 'value': 'I7-1165G7 16G/512G'}]
# 1    [{'key': 'Size', 'value': 'i711390H-32GB+1TB'}]
# 3        [{'key': 'Style', 'value': 'Mini_B_5700G'}]
# 4  [{'key': 'Style', 'value': 'Apple M2 Chip'}, {...
# 6                                                 []
#
#                               manufacturerAttributes  category sub-category
# 0  [{'key': 'Thunderbolt 4.0 Type-C Port', 'value...  Desktops        Minis
# 1                                                 []  Desktops        Minis
# 3                                                 []  Desktops       Towers
# 4                                                 []  Desktops        Minis
# 6                                                 []  Desktops  All-in-Ones

# %% [markdown]
# ### We want both "relational" (i.e. desktop/laptop spec data) and unstructured (i.e. reviews) data for each product in our db
# So we need to drop:
# * products from the `crawler` table that don't have any reviews
# * products from the `reviews` table that we've removed from the `crawler` table due to data issues

# %%
crawler_df = crawler_df[crawler_df['hasReviews'] == True]

# %%
reviews_df = reviews_df[reviews_df.productAsin.isin(crawler_df.asin)]
len(reviews_df)
# Out:
# 23231

# %%
crawler_df.drop(columns=['reviewsLink', 'hasReviews'], inplace=True)
crawler_df.head()
# Out:
#                                                title  \
# 0  Mini PC, 11th Intel i7-1165G7(up to 4.7GHz) Th...
# 1  GEEKOM Mini IT11 Mini PC, 1TB Intel i7-11390H ...
# 3  AVGPC Q-Box Mini Series PC - AMD Ryzen 5 5600G...
# 4  Apple 2023 Mac Mini Desktop Computer M2 chip w...
# 6  HP Chromebase 21.5" All-in-One Desktop, Intel ...
#
#                                     url        asin   brand   price  stars  \
# 0  https://www.amazon.com/dp/B0BNM4WLBJ  B0BNM4WLBJ  sinbun  529.00    4.4
# 1  https://www.amazon.com/dp/B0BQVM2XL6  B0BQVM2XL6  GEEKOM  599.99    4.7
# 3  https://www.amazon.com/dp/B099CHVFJJ  B099CHVFJJ   AVGPC  549.00    3.9
# 4  https://www.amazon.com/dp/B0BSHGHGXR  B0BSHGHGXR   Apple  559.00    4.6
# 6  https://www.amazon.com/dp/B099P4T81H  B099P4T81H      HP  545.00    4.3
#
#    reviewsCount                                     thumbnailImage  \
# 0          14.0  https://m.media-amazon.com/images/I/61oop4yoyF...
# 1          54.0  https://m.media-amazon.com/images/I/51W6MBfVCT...
# 3          23.0  https://m.media-amazon.com/images/I/61LAnQI-iH...
# 4         184.0  https://m.media-amazon.com/images/I/61La8PAa42...
# 6         264.0  https://m.media-amazon.com/images/I/81w3miL-DH...
#
#                                          description  \
# 0                                               None
# 1                                               None
# 3  Product images used on this page are for illus...
# 4                                               None
# 6  Change your perspective on home PCs with the H...
#
#                                             features  \
# 0  [【11th Intel Core i7 processor】11th i7 mini PC...
# 1  [[A Mini PC with An Upgraded Processor] GEEKOM...
# 3  [AMD Ryzen 5 5600G 3.9Ghz with Integrated AMD ...
# 4  [SUPERCHARGED BY M2 — Get more done faster wit...
# 6  [FLEXIBLE FAMILY FUN – Designed to live at the...
#
#                                           attributes  \
# 0  [{'key': 'Processor', 'value': '4.7 GHz core_i...
# 1  [{'key': 'Standing screen display size', 'valu...
# 3  [{'key': 'Processor', 'value': '4.8 GHz ryzen_...
# 4                                                 []
# 6  [{'key': 'Standing screen display size', 'valu...
#
#                                         variantAsins  \
# 0               [B0BNM4WLBJ, B0B8D2D7RN, B0BQ2BBRDV]
# 1                           [B0BQVM2XL6, B0BQWCQ7ZY]
# 3  [B099CHVFJJ, B09X2JCX8Z, B0BGYRWRH7, B099CSM7L...
# 4   [B0BSHGHGXR, B0BSHFS6XX, B0BSHGHGXR, B0BSHGTPMV]
# 6                                                 []
#
#                                    variantAttributes  \
# 0   [{'key': 'Size', 'value': 'I7-1165G7 16G/512G'}]
# 1    [{'key': 'Size', 'value': 'i711390H-32GB+1TB'}]
# 3        [{'key': 'Style', 'value': 'Mini_B_5700G'}]
# 4  [{'key': 'Style', 'value': 'Apple M2 Chip'}, {...
# 6                                                 []
#
#                               manufacturerAttributes  category sub-category
# 0  [{'key': 'Thunderbolt 4.0 Type-C Port', 'value...  Desktops        Minis
# 1                                                 []  Desktops        Minis
# 3                                                 []  Desktops       Towers
# 4                                                 []  Desktops        Minis
# 6                                                 []  Desktops  All-in-Ones

# %%
print(len(crawler_df))
print(crawler_df.isnull().sum())
# Out:
# 1661
# title                       0
# url                         0
# asin                        0
# brand                       0
# price                       0
# stars                       0
# reviewsCount                0
# thumbnailImage              0
# description               579
# features                    0
# attributes                  0
# variantAsins                0
# variantAttributes           0
# manufacturerAttributes      0
# category                    0
# sub-category                0
# dtype: int64

# %%
# create a new column in crawler_df that equals 1 if the product is a bestseller, 0 otherwise
crawler_df['bestseller'] = crawler_df['asin'].isin(bestsellers_df['asin']).astype(int)

# %%
crawler_df.head()
# Out:
#                                                title  \
# 0  Mini PC, 11th Intel i7-1165G7(up to 4.7GHz) Th...
# 1  GEEKOM Mini IT11 Mini PC, 1TB Intel i7-11390H ...
# 3  AVGPC Q-Box Mini Series PC - AMD Ryzen 5 5600G...
# 4  Apple 2023 Mac Mini Desktop Computer M2 chip w...
# 6  HP Chromebase 21.5" All-in-One Desktop, Intel ...
#
#                                     url        asin   brand   price  stars  \
# 0  https://www.amazon.com/dp/B0BNM4WLBJ  B0BNM4WLBJ  sinbun  529.00    4.4
# 1  https://www.amazon.com/dp/B0BQVM2XL6  B0BQVM2XL6  GEEKOM  599.99    4.7
# 3  https://www.amazon.com/dp/B099CHVFJJ  B099CHVFJJ   AVGPC  549.00    3.9
# 4  https://www.amazon.com/dp/B0BSHGHGXR  B0BSHGHGXR   Apple  559.00    4.6
# 6  https://www.amazon.com/dp/B099P4T81H  B099P4T81H      HP  545.00    4.3
#
#    reviewsCount                                     thumbnailImage  \
# 0          14.0  https://m.media-amazon.com/images/I/61oop4yoyF...
# 1          54.0  https://m.media-amazon.com/images/I/51W6MBfVCT...
# 3          23.0  https://m.media-amazon.com/images/I/61LAnQI-iH...
# 4         184.0  https://m.media-amazon.com/images/I/61La8PAa42...
# 6         264.0  https://m.media-amazon.com/images/I/81w3miL-DH...
#
#                                          description  \
# 0                                               None
# 1                                               None
# 3  Product images used on this page are for illus...
# 4                                               None
# 6  Change your perspective on home PCs with the H...
#
#                                             features  \
# 0  [【11th Intel Core i7 processor】11th i7 mini PC...
# 1  [[A Mini PC with An Upgraded Processor] GEEKOM...
# 3  [AMD Ryzen 5 5600G 3.9Ghz with Integrated AMD ...
# 4  [SUPERCHARGED BY M2 — Get more done faster wit...
# 6  [FLEXIBLE FAMILY FUN – Designed to live at the...
#
#                                           attributes  \
# 0  [{'key': 'Processor', 'value': '4.7 GHz core_i...
# 1  [{'key': 'Standing screen display size', 'valu...
# 3  [{'key': 'Processor', 'value': '4.8 GHz ryzen_...
# 4                                                 []
# 6  [{'key': 'Standing screen display size', 'valu...
#
#                                         variantAsins  \
# 0               [B0BNM4WLBJ, B0B8D2D7RN, B0BQ2BBRDV]
# 1                           [B0BQVM2XL6, B0BQWCQ7ZY]
# 3  [B099CHVFJJ, B09X2JCX8Z, B0BGYRWRH7, B099CSM7L...
# 4   [B0BSHGHGXR, B0BSHFS6XX, B0BSHGHGXR, B0BSHGTPMV]
# 6                                                 []
#
#                                    variantAttributes  \
# 0   [{'key': 'Size', 'value': 'I7-1165G7 16G/512G'}]
# 1    [{'key': 'Size', 'value': 'i711390H-32GB+1TB'}]
# 3        [{'key': 'Style', 'value': 'Mini_B_5700G'}]
# 4  [{'key': 'Style', 'value': 'Apple M2 Chip'}, {...
# 6                                                 []
#
#                               manufacturerAttributes  category sub-category  \
# 0  [{'key': 'Thunderbolt 4.0 Type-C Port', 'value...  Desktops        Minis
# 1                                                 []  Desktops        Minis
# 3                                                 []  Desktops       Towers
# 4                                                 []  Desktops        Minis
# 6                                                 []  Desktops  All-in-Ones
#
#    bestseller
# 0           0
# 1           0
# 3           0
# 4           1
# 6           0

# %% [markdown]
# ## Make a column that combines all text data for semantic similarity search

# %%
import string

def clean_string(text):                                                                                           
    return ''.join(char for char in text if char.isalnum() or char in string.punctuation + ' ')

# %%
# replace empty lists in the features col with an empty string
crawler_df['features'] = crawler_df['features'].apply(lambda x: '' if x == [] else x)

# %%
crawler_df['features_temp'] = crawler_df['features'].apply(lambda x: '. '.join(x) if isinstance(x, list) else x).apply(clean_string)

# %%
crawler_df['description'].fillna('', inplace=True)
crawler_df['description_temp'] = crawler_df['description'].apply(clean_string)

# %%
crawler_df['seller_text'] = crawler_df['features_temp'] + '. ' + crawler_df['description_temp']
crawler_df.drop(columns=['description_temp', 'features_temp'], inplace=True)

crawler_df['title_text'] = crawler_df['title'].apply(clean_string)
crawler_df['all_product_text'] = crawler_df['seller_text'] + '. ' + crawler_df['title_text']

# %%
crawler_df.head()
# Out:
#                                                title  \
# 0  Mini PC, 11th Intel i7-1165G7(up to 4.7GHz) Th...
# 1  GEEKOM Mini IT11 Mini PC, 1TB Intel i7-11390H ...
# 3  AVGPC Q-Box Mini Series PC - AMD Ryzen 5 5600G...
# 4  Apple 2023 Mac Mini Desktop Computer M2 chip w...
# 6  HP Chromebase 21.5" All-in-One Desktop, Intel ...
#
#                                     url        asin   brand   price  stars  \
# 0  https://www.amazon.com/dp/B0BNM4WLBJ  B0BNM4WLBJ  sinbun  529.00    4.4
# 1  https://www.amazon.com/dp/B0BQVM2XL6  B0BQVM2XL6  GEEKOM  599.99    4.7
# 3  https://www.amazon.com/dp/B099CHVFJJ  B099CHVFJJ   AVGPC  549.00    3.9
# 4  https://www.amazon.com/dp/B0BSHGHGXR  B0BSHGHGXR   Apple  559.00    4.6
# 6  https://www.amazon.com/dp/B099P4T81H  B099P4T81H      HP  545.00    4.3
#
#    reviewsCount                                     thumbnailImage  \
# 0          14.0  https://m.media-amazon.com/images/I/61oop4yoyF...
# 1          54.0  https://m.media-amazon.com/images/I/51W6MBfVCT...
# 3          23.0  https://m.media-amazon.com/images/I/61LAnQI-iH...
# 4         184.0  https://m.media-amazon.com/images/I/61La8PAa42...
# 6         264.0  https://m.media-amazon.com/images/I/81w3miL-DH...
#
#                                          description  \
# 0
# 1
# 3  Product images used on this page are for illus...
# 4
# 6  Change your perspective on home PCs with the H...
#
#                                             features  \
# 0  [【11th Intel Core i7 processor】11th i7 mini PC...
# 1  [[A Mini PC with An Upgraded Processor] GEEKOM...
# 3  [AMD Ryzen 5 5600G 3.9Ghz with Integrated AMD ...
# 4  [SUPERCHARGED BY M2 — Get more done faster wit...
# 6  [FLEXIBLE FAMILY FUN – Designed to live at the...
#
#                                           attributes  \
# 0  [{'key': 'Processor', 'value': '4.7 GHz core_i...
# 1  [{'key': 'Standing screen display size', 'valu...
# 3  [{'key': 'Processor', 'value': '4.8 GHz ryzen_...
# 4                                                 []
# 6  [{'key': 'Standing screen display size', 'valu...
#
#                                         variantAsins  \
# 0               [B0BNM4WLBJ, B0B8D2D7RN, B0BQ2BBRDV]
# 1                           [B0BQVM2XL6, B0BQWCQ7ZY]
# 3  [B099CHVFJJ, B09X2JCX8Z, B0BGYRWRH7, B099CSM7L...
# 4   [B0BSHGHGXR, B0BSHFS6XX, B0BSHGHGXR, B0BSHGTPMV]
# 6                                                 []
#
#                                    variantAttributes  \
# 0   [{'key': 'Size', 'value': 'I7-1165G7 16G/512G'}]
# 1    [{'key': 'Size', 'value': 'i711390H-32GB+1TB'}]
# 3        [{'key': 'Style', 'value': 'Mini_B_5700G'}]
# 4  [{'key': 'Style', 'value': 'Apple M2 Chip'}, {...
# 6                                                 []
#
#                               manufacturerAttributes  category sub-category  \
# 0  [{'key': 'Thunderbolt 4.0 Type-C Port', 'value...  Desktops        Minis
# 1                                                 []  Desktops        Minis
# 3                                                 []  Desktops       Towers
# 4                                                 []  Desktops        Minis
# 6                                                 []  Desktops  All-in-Ones
#
#    bestseller                                        seller_text  \
# 0           0  11th Intel Core i7 processor11th i7 mini PC co...
# 1           0  [A Mini PC with An Upgraded Processor] GEEKOM ...
# 3           0  AMD Ryzen 5 5600G 3.9Ghz with Integrated AMD R...
# 4           1  SUPERCHARGED BY M2  Get more done faster with ...
# 6           0  FLEXIBLE FAMILY FUN  Designed to live at the h...
#
#                                           title_text  \
# 0  Mini PC, 11th Intel i7-1165G7(up to 4.7GHz) Th...
# 1  GEEKOM Mini IT11 Mini PC, 1TB Intel i7-11390H ...
# 3  AVGPC Q-Box Mini Series PC - AMD Ryzen 5 5600G...
# 4  Apple 2023 Mac Mini Desktop Computer M2 chip w...
# 6  HP Chromebase 21.5" All-in-One Desktop, Intel ...
#
#                                     all_product_text
# 0  11th Intel Core i7 processor11th i7 mini PC co...
# 1  [A Mini PC with An Upgraded Processor] GEEKOM ...
# 3  AMD Ryzen 5 5600G 3.9Ghz with Integrated AMD R...
# 4  SUPERCHARGED BY M2  Get more done faster with ...
# 6  FLEXIBLE FAMILY FUN  Designed to live at the h...

# %%
crawler_df.to_excel('cleaned_crawler_data.xlsx')

# %% [markdown]
# ## Clean reviews data

# %%
reviews_df.head()
# Out:
#   productAsin  ratingScore                                        reviewTitle  \
# 0  B0BYJWRSC1            4                                     Painful Laptop
# 1  B0BYJWRSC1            5                               Has all the features
# 2  B0BYJWRSC1            5                                      Great Service
# 3  B0BT6W36HL            5  Lots of performance packed into a thin and lig...
# 4  B0BT6W36HL            5                                great AMOLED screen
#
#                                            reviewUrl  \
# 0  https://www.amazon.com/gp/customer-reviews/R6N...
# 1  https://www.amazon.com/gp/customer-reviews/R39...
# 2  https://www.amazon.com/gp/customer-reviews/R3V...
# 3  https://www.amazon.com/gp/customer-reviews/R2V...
# 4  https://www.amazon.com/gp/customer-reviews/R37...
#
#                 reviewReaction  \
# 0
# 1
# 2
# 3
# 4  5 people found this helpful
#
#                                           reviewedIn        date  \
# 0    Reviewed in the United States 🇺🇸 on May 6, 2023  2023-05-06
# 1  Reviewed in the United States 🇺🇸 on April 20, ...  2023-04-20
# 2  Reviewed in the United States 🇺🇸 on April 26, ...  2023-04-26
# 3       Reviewed in the United States on May 6, 2023  2023-05-06
# 4     Reviewed in the United States on April 3, 2023  2023-04-03
#
#          country countryCode  \
# 0  United States          🇺🇸
# 1  United States          🇺🇸
# 2  United States          🇺🇸
# 3  United States        None
# 4  United States        None
#
#                                    reviewDescription
# 0  This is a fast and elegant looking Windows 11 ...
# 1  This laptop is fast! 64 mb of ram really crank...
# 2     Fast delivery and product exactly as described
# 3  The Samsung 16" Galaxy Book3 Pro Business Lapt...
# 4  I bought the Book3 Ultra version of this lapto...

# %%
display(reviews_df.country.value_counts().to_frame())
reviews_df.loc[reviews_df['country'] == 'Germany', 'reviewDescription'].iloc[0]
# Out:
#                 country
# United States     23407
# Mexico              289
# Canada              105
# Germany              36
# Brazil               35
# United Kingdom       22
# Spain                14
# France               13
# Italy                12
# Singapore            10
# Australia             4
# Japan                 3
# 'Der HISTTON Mini PC wurde gut verpackt in einem Karton geliefert.Enthalten ist neben dem PC auch Zubehör:-Das Netzteil mit Anschlusskabel und Netzkabeln für EU (Stecker E+F) und einem für (vor allem) Großbritannien (Stecker Typ G)-2 Aufschraubbare WLAN-Antennen-Strom sowie Datenkabel für zusätzliches SATA-Laufwerk-Befestigungsmaterial für Laufwerk, Montage an Halterungen-Befestigungsplatte-Eine DVD mit Software (macht keinen seriösen Eindruck)-Eine englischsprachige AnleitungNicht mitgeliefert wurde ein Tischständer, der in der Beschreibung gezeigt wird.Der Computer hat ein sehr robust wirkendes und einwandfrei verarbeitete Gehäuse aus Metall (Aluminium) mit Kühlrippen. Das sollte die Wärme dieses passiv gekühlten Geräts gut ableiten.Der Computer ist offensichtlich eher für den Einsatz in Industrie, Produktion etc. vorgesehen und nicht für den normalen Schreibtisch-Einsatz -aber dennoch kann man ihn natürlich auch da nützen.Der Mini PC verfügt über eine riesige Anzahl an Anschlüssen:An der Front gibt es neben einem COM-Port einen SIM-Steckplatz und vier USB 2-AnschlüsseDaneben ist rechts der Einschaltknopf mit einer blauen LED-BetriebsanzeigeAn der Rückseite befinden sich:-Zwei Antennen-Anschlüsse (Gewinde) für WLAN-Antennen -zwei sind ja im Lieferumfang-3,5“-Anschluss für Lautsprecher-3,5“-Anschluss für Mikrofon-2 Ethernet-Stecker (Gigabit)-4 USB 3.0-Ports-Ein USB C-Port (TPC)-Ein Display Port (EDP)-Ein HDMI-Port (HD)-Daneben der DC IN-Anschluss fürs externe Netzteil-Unten ganze 5 COM-PortsInsgesamt sehr viele Anschlüsse. Für normale Nutzer werden die zahlreichen COM-Ports aber wenig interessant sein, eher für Spezialanwendungen.Hardware im InnerenDer Mini PC lässt sich leicht über 4 Schrauben an der Unterseite öffnen -die Bodenplatte lässt sich dann sofort und einfach abnehmen.Schon hat man Zugriff aufs Innenleben: Insgesamt ist das Gehäuse übersichtlich, bei meinem Exemplar war bereits ein 16GB RAM-Modul DDR4 2666 (Marke WEIDIAN) installiert, ein zweiter Steckplatz ist frei.Die Module lassen sich ganz normal austauschen.Die SSD (Marke KingFast) F6M.2 scheint auch einfach austauschbar zu sein.Als Prozessor kommt ein 4-Kern Intel Core i5 8265U zum Einsatz.Außerdem gibt es eine integrierte Intel®UHD 620 Grafik.Aufstellen/Platzieren des Computers:\u2028Der Computer verfügt unten über gummierte Standfüße und kann daher natürlich einfach normal auf einen flachen Untergrund gestellt werden. Ebenso befindet sich an der Unterseite diverse Bohrungen, so dass man den PC an der Wand oder diversen Befestigungen montieren kann, auch eine Befestigungsplatte ist dabei. So kann man den PC auch z.B. an die Rückseite eines Monitors mit passenden Gewinden schrauben.An den Seiten der Bodenplatte sind auch vier Öffnungen, womit man den PC wohl z.b. einfach an Verankerungen oder einhängen oder direkt irgendwo anschrauben könnte.InbetriebnahmeDer Computer ließ sich sofort in betrieb nehmen: Windows 10 Professional war bereits vorinstalliert und aktiviert. Das System war bereits eingerichtet und ein „Histton“-Account angelegt.Wie vertrauenswürdig das ist, und ob man das System lieber neu installieren will, muss jeder für sich selbst entscheiden.Auf der mitgelieferten DVD dürften aber nur Treiber sein, ein zusätzliches externes DVD-Laufwerk wird zur Nutzung der DVD benötigt.LeistungDer Computer sollte auf jeden Fall genug Leistung für Alltags-Aufgaben bieten. Natürlich ist er wegen dem lüfterlosen Design und der Onboard-Grafik für Spiele, grafikaufwendige Anwendungen etc. ziemlich ungeeignet.Für einen stromsparenden, lüfterlosen PC scheinter er aber eine brauchbare Leistung zu bringen.Er startet schnell genug und alle normalen Anwendungen laufen flüssig.Kühlung, WärmeDas Gehäuse wird an den Kühlrippen, speziell auf der linken Seite, sehr heißt im Betrieb, dass man ihn gerade noch kurz anfassen kann. Ich hoffe, das Kühldesign ist durchdacht, und das sollte so sein, denn ich hatte noch keinen derartig passiv gekühlten PC.Fazit:\u2028Ein sehr speziell ...

# %%
reviews_df = reviews_df[reviews_df.country.isin(['United States', 'Canada', 'United Kingdom', 'Australia'])]

# %%
reviews_df.head()
# Out:
#   productAsin  ratingScore                                        reviewTitle  \
# 0  B0BYJWRSC1            4                                     Painful Laptop
# 1  B0BYJWRSC1            5                               Has all the features
# 2  B0BYJWRSC1            5                                      Great Service
# 3  B0BT6W36HL            5  Lots of performance packed into a thin and lig...
# 4  B0BT6W36HL            5                                great AMOLED screen
#
#                                            reviewUrl  \
# 0  https://www.amazon.com/gp/customer-reviews/R6N...
# 1  https://www.amazon.com/gp/customer-reviews/R39...
# 2  https://www.amazon.com/gp/customer-reviews/R3V...
# 3  https://www.amazon.com/gp/customer-reviews/R2V...
# 4  https://www.amazon.com/gp/customer-reviews/R37...
#
#                 reviewReaction  \
# 0
# 1
# 2
# 3
# 4  5 people found this helpful
#
#                                           reviewedIn        date  \
# 0    Reviewed in the United States 🇺🇸 on May 6, 2023  2023-05-06
# 1  Reviewed in the United States 🇺🇸 on April 20, ...  2023-04-20
# 2  Reviewed in the United States 🇺🇸 on April 26, ...  2023-04-26
# 3       Reviewed in the United States on May 6, 2023  2023-05-06
# 4     Reviewed in the United States on April 3, 2023  2023-04-03
#
#          country countryCode  \
# 0  United States          🇺🇸
# 1  United States          🇺🇸
# 2  United States          🇺🇸
# 3  United States        None
# 4  United States        None
#
#                                    reviewDescription
# 0  This is a fast and elegant looking Windows 11 ...
# 1  This laptop is fast! 64 mb of ram really crank...
# 2     Fast delivery and product exactly as described
# 3  The Samsung 16" Galaxy Book3 Pro Business Lapt...
# 4  I bought the Book3 Ultra version of this lapto...

# %%
reviews_df['reviewDescription'] = reviews_df['reviewDescription'].apply(clean_string)
reviews_df['reviewTitle'] = reviews_df['reviewTitle'].apply(clean_string)

reviews_df['all_review_text'] = reviews_df['reviewTitle'] + '. ' + reviews_df['reviewDescription']

reviews_df.head()
# Out:
#   productAsin  ratingScore                                        reviewTitle  \
# 0  B0BYJWRSC1            4                                     Painful Laptop
# 1  B0BYJWRSC1            5                               Has all the features
# 2  B0BYJWRSC1            5                                      Great Service
# 3  B0BT6W36HL            5  Lots of performance packed into a thin and lig...
# 4  B0BT6W36HL            5                                great AMOLED screen
#
#                                            reviewUrl  \
# 0  https://www.amazon.com/gp/customer-reviews/R6N...
# 1  https://www.amazon.com/gp/customer-reviews/R39...
# 2  https://www.amazon.com/gp/customer-reviews/R3V...
# 3  https://www.amazon.com/gp/customer-reviews/R2V...
# 4  https://www.amazon.com/gp/customer-reviews/R37...
#
#                 reviewReaction  \
# 0
# 1
# 2
# 3
# 4  5 people found this helpful
#
#                                           reviewedIn        date  \
# 0    Reviewed in the United States 🇺🇸 on May 6, 2023  2023-05-06
# 1  Reviewed in the United States 🇺🇸 on April 20, ...  2023-04-20
# 2  Reviewed in the United States 🇺🇸 on April 26, ...  2023-04-26
# 3       Reviewed in the United States on May 6, 2023  2023-05-06
# 4     Reviewed in the United States on April 3, 2023  2023-04-03
#
#          country countryCode  \
# 0  United States          🇺🇸
# 1  United States          🇺🇸
# 2  United States          🇺🇸
# 3  United States        None
# 4  United States        None
#
#                                    reviewDescription  \
# 0  This is a fast and elegant looking Windows 11 ...
# 1  This laptop is fast! 64 mb of ram really crank...
# 2     Fast delivery and product exactly as described
# 3  The Samsung 16" Galaxy Book3 Pro Business Lapt...
# 4  I bought the Book3 Ultra version of this lapto...
#
#                                      all_review_text
# 0  Painful Laptop. This is a fast and elegant loo...
# 1  Has all the features. This laptop is fast! 64 ...
# 2  Great Service. Fast delivery and product exact...
# 3  Lots of performance packed into a thin and lig...
# 4  great AMOLED screen. I bought the Book3 Ultra ...

# %%
# calculate a weighted average of the numPeopleFoundHelpful column by grouping on productAsin and taking the sum of numPeopleFoundHelpful divided by the sum of 1 / (1 + date - date.min())
reviews_df['numPeopleFoundHelpful'] = reviews_df['reviewReaction'].apply(lambda x: 1 if x == '' else 2 if x.startswith('One') else 1 + int(x.split(' ')[0].replace(',', '')))
reviews_df['totalHelpful'] = reviews_df.groupby('productAsin')['numPeopleFoundHelpful'].transform('sum')
reviews_df['wavgHelpfulness'] = reviews_df['numPeopleFoundHelpful'] / reviews_df['totalHelpful']
reviews_df.head()
# Out:
#   productAsin  ratingScore                                        reviewTitle  \
# 0  B0BYJWRSC1            4                                     Painful Laptop
# 1  B0BYJWRSC1            5                               Has all the features
# 2  B0BYJWRSC1            5                                      Great Service
# 3  B0BT6W36HL            5  Lots of performance packed into a thin and lig...
# 4  B0BT6W36HL            5                                great AMOLED screen
#
#                                            reviewUrl  \
# 0  https://www.amazon.com/gp/customer-reviews/R6N...
# 1  https://www.amazon.com/gp/customer-reviews/R39...
# 2  https://www.amazon.com/gp/customer-reviews/R3V...
# 3  https://www.amazon.com/gp/customer-reviews/R2V...
# 4  https://www.amazon.com/gp/customer-reviews/R37...
#
#                 reviewReaction  \
# 0
# 1
# 2
# 3
# 4  5 people found this helpful
#
#                                           reviewedIn        date  \
# 0    Reviewed in the United States 🇺🇸 on May 6, 2023  2023-05-06
# 1  Reviewed in the United States 🇺🇸 on April 20, ...  2023-04-20
# 2  Reviewed in the United States 🇺🇸 on April 26, ...  2023-04-26
# 3       Reviewed in the United States on May 6, 2023  2023-05-06
# 4     Reviewed in the United States on April 3, 2023  2023-04-03
#
#          country countryCode  \
# 0  United States          🇺🇸
# 1  United States          🇺🇸
# 2  United States          🇺🇸
# 3  United States        None
# 4  United States        None
#
#                                    reviewDescription  \
# 0  This is a fast and elegant looking Windows 11 ...
# 1  This laptop is fast! 64 mb of ram really crank...
# 2     Fast delivery and product exactly as described
# 3  The Samsung 16" Galaxy Book3 Pro Business Lapt...
# 4  I bought the Book3 Ultra version of this lapto...
#
#                                      all_review_text  numPeopleFoundHelpful  \
# 0  Painful Laptop. This is a fast and elegant loo...                      1
# 1  Has all the features. This laptop is fast! 64 ...                      1
# 2  Great Service. Fast delivery and product exact...                      1
# 3  Lots of performance packed into a thin and lig...                      1
# 4  great AMOLED screen. I bought the Book3 Ultra ...                      6
#
#    totalHelpful  wavgHelpfulness
# 0             3         0.333333
# 1             3         0.333333
# 2             3         0.333333
# 3             7         0.142857
# 4             7         0.857143

# %%
reviews_df = reviews_df[['productAsin',
 'ratingScore',
 'reviewTitle',
 'reviewUrl',
 'reviewReaction',
 'date',
 'reviewDescription',
 'all_review_text',
 'wavgHelpfulness']]
# Out:
#       productAsin  ratingScore  \
# 0      B0BYJWRSC1            4
# 1      B0BYJWRSC1            5
# 2      B0BYJWRSC1            5
# 3      B0BT6W36HL            5
# 4      B0BT6W36HL            5
# ...           ...          ...
# 23945  B08MMQH98H            5
# 23946  B08MMQH98H            5
# 23947  B08MMQH98H            5
# 23948  B08MMQH98H            5
# 23949  B08MMQH98H            2
#
#                                              reviewTitle  \
# 0                                         Painful Laptop
# 1                                   Has all the features
# 2                                          Great Service
# 3      Lots of performance packed into a thin and lig...
# 4                                    great AMOLED screen
# ...                                                  ...
# 23945  Seller Stepped Up and Handled a Problem in a G...
# 23946                                   Nice Refurb Unit
# 23947                                   Looks brand new!
# 23948                            Great Business Machine!
# 23949                  Not happy at all with this model!
#
#                                                reviewUrl  \
# 0      https://www.amazon.com/gp/customer-reviews/R6N...
# 1      https://www.amazon.com/gp/customer-reviews/R39...
# 2      https://www.amazon.com/gp/customer-reviews/R3V...
# 3      https://www.amazon.com/gp/customer-reviews/R2V...
# 4      https://www.amazon.com/gp/customer-reviews/R37...
# ...                                                  ...
# 23945  https://www.amazon.com/gp/customer-reviews/R30...
# 23946  https://www.amazon.com/gp/customer-reviews/R4J...
# 23947  https://www.amazon.com/gp/customer-reviews/R3R...
# 23948  https://www.amazon.com/gp/customer-reviews/RFS...
# 23949  https://www.amazon.com/gp/customer-reviews/R25...
#
#                       reviewReaction        date  \
# 0                                     2023-05-06
# 1                                     2023-04-20
# 2                                     2023-04-26
# 3                                     2023-05-06
# 4        5 people found this helpful  2023-04-03
# ...                              ...         ...
# 23945    2 people found this helpful  2023-03-05
# 23946                                 2023-02-18
# 23947    4 people found this helpful  2023-03-03
# 23948                                 2023-04-09
# 23949  One person found this helpful  2023-03-29
#
#                                        reviewDescription  \
# 0      This is a fast and elegant looking Windows 11 ...
# 1      This laptop is fast! 64 mb of ram really crank...
# 2         Fast delivery and product exactly as described
# 3      The Samsung 16" Galaxy Book3 Pro Business Lapt...
# 4      I bought the Book3 Ultra version of this lapto...
# ...                                                  ...
# 23945  While it is a great little machine, before I b...
# 23946  I ordered are refurbished Levono Thinkcentre s...
# 23947  After using it for one month i don't have any ...
# 23948  This machine served my customer's needs perfec...
# 23949  I bought three of these, two from one dealer a...
#
#                                          all_review_text  wavgHelpfulness
# 0      Painful Laptop. This is a fast and elegant loo...         0.333333
# 1      Has all the features. This laptop is fast! 64 ...         0.333333
# 2      Great Service. Fast delivery and product exact...         0.333333
# 3      Lots of performance packed into a thin and lig...         0.142857
# 4      great AMOLED screen. I bought the Book3 Ultra ...         0.857143
# ...                                                  ...              ...
# 23945  Seller Stepped Up and Handled a Problem in a G...         0.033333
# 23946  Nice Refurb Unit. I ordered are refurbished Le...         0.011111
# 23947  Looks brand new!. After using it for one month...         0.055556
# 23948  Great Business Machine!. This machine served m...         0.011111
# 23949  Not happy at all with this model!. I bought th...         0.022222
#
# [23538 rows x 9 columns]

# %%
product_data = pd.read_excel('cleaned_crawler_data.xlsx')
product_data.asin.nunique()
# Out:
# 1661

# %%
non_matchers = list(set(product_data.asin.unique()) - set(reviews_df.productAsin.unique())) + list(set(reviews_df.productAsin.unique()) - set(product_data.asin.unique()))
reviews_df = reviews_df[~reviews_df.productAsin.isin(non_matchers)]
product_data = product_data[~product_data.asin.isin(non_matchers)]
print(f'unique products in reviews_df: {reviews_df.productAsin.nunique()}')
print(f'unique products in product_df: {product_data.asin.nunique()}')  

product_data.to_excel('final_product_data.xlsx', index=False)
reviews_df.to_excel('final_reviews_data.xlsx', index=False)
# Out:
# unique products in reviews_df: 1660
# unique products in product_df: 1660

# %% [markdown]
# ## Flatten attributes

# %%
def map_os(os_string):
    if os_string is None:
        return None
    os_string = os_string.lower()
    if "window" in os_string or "win" in os_string or "w11" in os_string or "w-11" in os_string or "w 11" in os_string:
        return "Windows"
    elif "mac" in os_string or "os x" in os_string or "ios" in os_string:
        return "macOS"
    elif "linux" in os_string or "ubuntu" in os_string:
        return "Linux"
    else:
        return os_string
    
import ast
import pandas as pd

# Assuming your original DataFrame is named product_data and the copy is product_df
product_df = product_data[['asin', 'attributes']].copy()
product_df['attributes'] = product_df['attributes'].apply(ast.literal_eval)

# Explode the list into individual rows
product_df = product_df.explode('attributes')
product_df = product_df[~product_df['attributes'].isnull()]

# Convert the dictionaries into two separate columns
product_df[['key', 'value']] = pd.DataFrame(product_df['attributes'].tolist(), index=product_df.index)

# Drop the 'attributes' column as it is no longer needed
product_df = product_df.drop(columns='attributes')

# Pivot the DataFrame so that each unique 'key' gets its own column, using asin as the index
product_df = product_df.pivot(index='asin', columns='key', values='value')

# Reset the index of the DataFrame
product_df = product_df.reset_index()

# Merge the pivoted DataFrame back to the original DataFrame
flat_product_df = pd.merge(product_data, product_df, on='asin', how='left')

flat_product_df[flat_product_df['Operating System'].apply(lambda x: isinstance(x, str))]


# drop if null in Brand, item model number, operating system, price, or processor
flat_product_df = flat_product_df.dropna(subset=['Brand', 'Item model number', 'Operating System', 'price', 'Processor'])
flat_product_df = flat_product_df[flat_product_df['Operating System'].apply(lambda x: isinstance(x, str))]
    
flat_product_df['Operating System'] = flat_product_df['Operating System'].apply(map_os)
flat_product_df = flat_product_df[['asin', 'Brand', 'Item model number', 'Operating System', 'price', 'RAM', 'Hard Drive', 'category', 'Series', 'Processor Brand', 'Processor', 'Chipset Brand', 'Graphics Coprocessor', 'variantAsins']]

# if `graphics coprocessor` contains `chipset brand` value, remove the matching string from `graphics coprocessor`
flat_product_df['Graphics Coprocessor'] = flat_product_df.apply(lambda row: row['Graphics Coprocessor'].replace(row['Chipset Brand'], '') if isinstance(row['Graphics Coprocessor'], str) and isinstance(row['Chipset Brand'], str) and row['Chipset Brand'].lower() in row['Graphics Coprocessor'].lower() else row['Graphics Coprocessor'], axis=1)
# strip leading and trailing whitespace
flat_product_df['Graphics Coprocessor'] = flat_product_df['Graphics Coprocessor'].apply(lambda x: x.strip() if isinstance(x, str) else x)
# set chipset brand to nan if graphics coprocessor is nan
flat_product_df['Chipset Brand'] = flat_product_df.apply(lambda row: np.nan if isinstance(row['Graphics Coprocessor'], float) and np.isnan(row['Graphics Coprocessor']) else row['Chipset Brand'], axis=1)

# drop instances where graphics coprocessor is nan but chipset brand is not nan
flat_product_df.loc[flat_product_df['Chipset Brand'].isnull() & flat_product_df['Graphics Coprocessor'].notnull()].index

flat_product_df = flat_product_df.drop(flat_product_df.loc[flat_product_df['Chipset Brand'].isnull() & flat_product_df['Graphics Coprocessor'].notnull()].index)

full_product_df = pd.merge(flat_product_df, product_data[['asin', 'bestseller', 'seller_text', 'title_text', 'url', 'stars', 'reviewsCount', 'thumbnailImage']], on='asin', how='left')
full_product_df = full_product_df[['asin', 'title_text', 'category', 'Series', 'Brand', 'Item model number', 'Operating System', 'price', 
                                   'RAM', 'Hard Drive', 'Processor Brand', 'Processor', 'Chipset Brand', 'Graphics Coprocessor', 
                                   'bestseller', 'seller_text', 'url', 'stars', 'reviewsCount', 'thumbnailImage', 'variantAsins']]
full_product_df.head(20)
# Out:
#           asin                                         title_text  category  \
# 0   B0BNM4WLBJ  Mini PC, 11th Intel i7-1165G7(up to 4.7GHz) Th...  Desktops
# 1   B0BQVM2XL6  GEEKOM Mini IT11 Mini PC, 1TB Intel i7-11390H ...  Desktops
# 2   B099CHVFJJ  AVGPC Q-Box Mini Series PC - AMD Ryzen 5 5600G...  Desktops
# 3   B099P4T81H  HP Chromebase 21.5" All-in-One Desktop, Intel ...  Desktops
# 4   B09YVWMLBP  Dell 2022 Newest Optiplex 3090 Micro Form Fact...  Desktops
# 5   B0BS2LCB1X  2018 Apple Mac Mini with 3.2GHz Intel Core i7 ...  Desktops
# 6   B0BWPKK7RN  Dell OptiPlex 7080 Micro Form Factor Mini Busi...  Desktops
# 7   B0B2KVQJM8  Acer Aspire C24-1700-UA91 AIO Desktop | 23.8" ...  Desktops
# 8   B0BM8YLTH8  [Gaming PC] KAMRUI Mini PC AMD Ryzen 5 5600U U...  Desktops
# 9   B0934RHLXD  HP 600 G1 SFF Computer Desktop PC, Intel Core ...  Desktops
# 10  B09WSKJ5DB  Dell Inspiron 3910 Desktop Computer Tower - 12...  Desktops
# 11  B09SHSQ5CF  Beelink SER5 Mini PC, AMD Ryzen 5 5500U (6C/12...  Desktops
# 12  B0B6523VBD  HP 2022 Newest All-in-One Desktop, 21.5" FHD D...  Desktops
# 13  B08CY7Q36R  Lenovo ThinkCentre M900 SFF Desktop Computer, ...  Desktops
# 14  B07RLW1QB8  HP Prodesk 600 G3 Micro Computer Mini PC (Inte...  Desktops
# 15  B0BFGD4C5T  Skytech Chronos Mini Gaming PC Desktop  AMD Ry...  Desktops
# 16  B0BDQPLRG7  Lenovo IdeaCentre AIO 3i - 2022 - All-in-One D...  Desktops
# 17  B09NF6S5PZ  HP Pavilion Gaming Desktop, AMD Radeon RX 5500...  Desktops
# 18  B0BRN8ND1S  MINISFORUM Mini PC UM690 AMD Ryzen 9 6900HX 8 ...  Desktops
# 19  B0B52WGJRR  Skytech Shiva II Gaming PC Desktop  Intel Core...  Desktops
#
#                                   Series           Brand  \
# 0                                BQM3 I7          Sinbun
# 1                              Mini IT11          GEEKOM
# 2                                  Q-Box           AVGPC
# 3                              22-aa0022              HP
# 4                               Optiplex            Dell
# 5                         Apple Mac Mini           Apple
# 6                               OptiPlex            Dell
# 7                          C24-1700-UA91            Acer
# 8                     AMR5-Ryzen 5 5600U          KAMRUI
# 9                  HP ProDesk 600 G1 SFF              HP
# 10                         Inspiron 3910            Dell
# 11                                  SER5         Beelink
# 12                                   AIO              HP
# 13                           ThinkCentre          Lenovo
# 14                               HP INC.              HP
# 15                          Chronos Mini  Skytech Gaming
# 16                     IdeaCentre AIO 3i          Lenovo
# 17  HP Pavilion Gaming Desktop TG01-2022              HP
# 18                                 UM690      MINISFORUM
# 19                              Shiva II  Skytech Gaming
#
#         Item model number Operating System   price            RAM  \
# 0       BQM3 i7 16/512 GB          Windows  529.00    512 GB DDR4
# 1               Mini IT11          Windows  599.99     32 GB DDR4
# 2              Q Box mini          Windows  549.00     16 GB DDR4
# 3               22-aa0022        chrome os  545.00      4 GB DDR4
# 4                    3090          Windows  624.13     16 GB DDR4
# 5               MRTT2LL/A            macOS  515.00           DDR4
# 6                    7080          Windows  599.00     32 GB DDR4
# 7            DQ.BJFAA.002          Windows  528.67      8 GB DDR4
# 8                    AMR5          Windows  479.00     16 GB DDR4
# 9                 ProDesk          Windows  268.00     16 GB DDR3
# 10      i3910-5157BLU-PUS          Windows  649.99     16 GB DDR4
# 11                    SEI          Windows  299.00     16 GB DDR4
# 12              22-df0224          Windows  589.00     16 GB DDR4
# 13                   M900          Windows  244.00     32 GB DDR4
# 14       Prodesk 600 (G3)          Windows  125.99  16 GB SO-DIMM
# 15  ST-CHRONOSM-0502-B-AM          Windows  780.38      8 GB DDR4
# 16             F0GJ0090US          Windows  860.91            NaN
# 17              TG01-2022          Windows  627.00      8 GB DDR4
# 18                  UM690          Windows  839.99     32 GB DDR5
# 19    ST-SHIVA2-0470-W-AM          Windows  999.99    500 GB DDR4
#
#                                            Hard Drive Processor Brand  \
# 0                                           16 GB SSD           Intel
# 1                                                1 TB           Intel
# 2                                          500 GB SSD             AMD
# 3                                          128 GB SSD           Intel
# 4                                          512 GB SSD           Intel
# 5                                          128 GB SSD           Intel
# 6                                            1 TB SSD           Intel
# 7                                          512 GB SSD           Intel
# 8   512 GB 512GB M.2 SSD Included, Support NVME/NG...             AMD
# 9                                          128 GB HDD           Intel
# 10                                          1 TB SSHD           Intel
# 11                                         500 GB SSD             AMD
# 12                                         512 GB SSD           Intel
# 13                                           1 TB SSD           Intel
# 14                                         512 GB SSD           Intel
# 15                                         500 GB SSD             AMD
# 16                                                SSD           Intel
# 17                                         512 GB SSD             AMD
# 18                                           1 TB SSD             AMD
# 19                                         500 GB SSD           Intel
#
#                      Processor Chipset Brand  Graphics Coprocessor  \
# 0              4.7 GHz core_i7           NaN                   NaN
# 1           2400 MHz apple_ci7           NaN                   NaN
# 2              4.8 GHz ryzen_5           NaN                   NaN
# 3   2.4 GHz pentium_gold_g5600         Intel      UHD Graphics 600
# 4              2.3 GHz core_i5         Intel          UHD Graphics
# 5            3.2 GHz apple_ci7         Intel      UHD Graphics 630
# 6              2.3 GHz core_i5         Intel          UHD Graphics
# 7            4.4 GHz apple_ci3           NaN                   NaN
# 8              4.2 GHz ryzen_5           AMD         Radeon Vega 7
# 9              3.4 GHz core_i7         Intel  Onboard  HD Graphics
# 10             4.4 GHz core_i5         Intel      UHD Graphics 730
# 11               4 GHz ryzen_5           NaN                   NaN
# 12               2 GHz celeron         Intel          UHD Graphics
# 13               4 GHz core_i7           NaN                   NaN
# 14             3.2 GHz core_i5         Intel       HD Graphics 630
# 15             3.6 GHz ryzen_5        NVIDIA                  3050
# 16             1.7 GHz core_i5         Intel      Iris Xe Graphics
# 17               4 GHz ryzen_3           AMD        Radeon RX 5500
# 18             4.9 GHz ryzen_9           NaN                   NaN
# 19             2.5 GHz core_i5        NVIDIA                  3060
#
#     bestseller                                        seller_text  \
# 0            0  11th Intel Core i7 processor11th i7 mini PC co...
# 1            0  [A Mini PC with An Upgraded Processor] GEEKOM ...
# 2            0  AMD Ryzen 5 5600G 3.9Ghz with Integrated AMD R...
# 3            0  FLEXIBLE FAMILY FUN  Designed to live at the h...
# 4            0  High Speed RAM And Enormous Space16GB high-ban...
# 5            0  This pre-owned product is not Apple certified,...
# 6            0  High Speed RAM And Enormous Space32GB high-ban...
# 7            0  SLIM. STYLISH. STUNNING: Save the clutter on y...
# 8            1  THE KEY TO VICTORYThe KAMRUI AMR5 mini gaming ...
# 9            1   POWERFUL PROCESSOR Configured with Intels top...
# 10           1  STAY PRODUCTIVE: Constructed with the latest 1...
# 11           1  Comparable Tower PerformanceThe Beelink SER5 M...
# 12           1  High Speed RAM And Enormous Space16GB DDR4 RAM...
# 13           1  Lenovo ThinkCentre M900 SFF Desktop Computer. ...
# 14           1  This Certified Refurbished product is tested a...
# 15           0  AMD Ryzen 5 3600 3.6GHz (4.2GHz Max Boost) CPU...
# 16           0  Built for heavy use: Engineered for heavy work...
# 17           0  GAME ON YOUR OWN TERMS  This potent PC keeps u...
# 18           0  Excellent PerformanceMINISFORUM Venus Series U...
# 19           0  INTEL Core i5 12400F 2.5GHz (4.4GHz Max Boost)...
#
#                                      url  stars  reviewsCount  \
# 0   https://www.amazon.com/dp/B0BNM4WLBJ    4.4            14
# 1   https://www.amazon.com/dp/B0BQVM2XL6    4.7            54
# 2   https://www.amazon.com/dp/B099CHVFJJ    3.9            23
# 3   https://www.amazon.com/dp/B099P4T81H    4.3           264
# 4   https://www.amazon.com/dp/B09YVWMLBP    5.0            10
# 5   https://www.amazon.com/dp/B0BS2LCB1X    4.6            29
# 6   https://www.amazon.com/dp/B0BWPKK7RN    4.1            13
# 7   https://www.amazon.com/dp/B0B2KVQJM8    4.5           110
# 8   https://www.amazon.com/dp/B0BM8YLTH8    4.5           166
# 9   https://www.amazon.com/dp/B0934RHLXD    3.9           262
# 10  https://www.amazon.com/dp/B09WSKJ5DB    4.3           369
# 11  https://www.amazon.com/dp/B09SHSQ5CF    4.4           179
# 12  https://www.amazon.com/dp/B0B6523VBD    4.4           174
# 13  https://www.amazon.com/dp/B08CY7Q36R    3.9           335
# 14  https://www.amazon.com/dp/B07RLW1QB8    3.5           126
# 15  https://www.amazon.com/dp/B0BFGD4C5T    4.3            76
# 16  https://www.amazon.com/dp/B0BDQPLRG7    4.5            82
# 17  https://www.amazon.com/dp/B09NF6S5PZ    4.3           409
# 18  https://www.amazon.com/dp/B0BRN8ND1S    4.4           142
# 19  https://www.amazon.com/dp/B0B52WGJRR    4.2            29
#
#                                        thumbnailImage  \
# 0   https://m.media-amazon.com/images/I/61oop4yoyF...
# 1   https://m.media-amazon.com/images/I/51W6MBfVCT...
# 2   https://m.media-amazon.com/images/I/61LAnQI-iH...
# 3   https://m.media-amazon.com/images/I/81w3miL-DH...
# 4   https://m.media-amazon.com/images/I/61TIHYXkb4...
# 5   https://m.media-amazon.com/images/I/61mujJvG+C...
# 6   https://m.media-amazon.com/images/I/51qO-k6MY1...
# 7   https://m.media-amazon.com/images/I/714AZcO8PL...
# 8   https://m.media-amazon.com/images/I/61oUaIuI0A...
# 9   https://m.media-amazon.com/images/I/81B91P9+6Y...
# 10  https://m.media-amazon.com/images/I/71ilwAO89y...
# 11  https://m.media-amazon.com/images/I/71Jxd4bZmg...
# 12  https://m.media-amazon.com/images/I/91-CdWQGWA...
# 13  https://m.media-amazon.com/images/I/71ez9IeXic...
# 14  https://m.media-amazon.com/images/I/61V1uUdDze...
# 15  https://m.media-amazon.com/images/I/91jHNGBFfl...
# 16  https://m.media-amazon.com/images/I/71rUl7OIqY...
# 17  https://m.media-amazon.com/images/I/81YNP1bMLp...
# 18  https://m.media-amazon.com/images/I/71C6QG66TM...
# 19  https://m.media-amazon.com/images/I/81tzr1Xc-Q...
#
#                                          variantAsins
# 0          ['B0BNM4WLBJ', 'B0B8D2D7RN', 'B0BQ2BBRDV']
# 1                        ['B0BQVM2XL6', 'B0BQWCQ7ZY']
# 2   ['B099CHVFJJ', 'B09X2JCX8Z', 'B0BGYRWRH7', 'B0...
# 3                                                  []
# 4   ['B0B2VB5ZT1', 'B0B2V1BJYX', 'B09YVWMLBP', 'B0...
# 5                                                  []
# 6   ['B0BWQ3F343', 'B0BX21XTPP', 'B0BWQ1PXL3', 'B0...
# 7                                                  []
# 8                        ['B0BM8YLTH8', 'B0BX82ZBMG']
# 9                                                  []
# 10  ['B09WSKJ5DB', 'B0C1KSLL76', 'B0C1KPCR7V', 'B0...
# 11         ['B09SHSQ5CF', 'B0C37472L6', 'B0B3XF3KD8']
# 12  ['B0B651YPLB', 'B0B6523VBD', 'B0B6523VBD', 'B0...
# 13                                                 []
# 14                       ['B07RLW1QB8', 'B07S24VMLZ']
# 15  ['B0BFGD4C5T', 'B09MSSDYQS', 'B0B52V47KB', 'B0...
# 16  ['B0BDQPLRG7', 'B0BXMXYT6Y', 'B0BDR1VXQX', 'B0...
# 17                       ['B09NF6S5PZ', 'B0BKFZF33V']
# 18  ['B0BRN8ND1S', 'B0C4FB15TM', 'B0C379S3KM', 'B0...
# 19                                                 []

# %%
reviews_df = reviews_df[['productAsin',
 'reviewUrl',
 'ratingScore',
 'reviewTitle',
 'reviewDescription',
 'date',
 'all_review_text',
 'numPeopleFoundHelpful',
 'wavgHelpfulness']]

# %%
reviews_df.head()
# Out:
#   productAsin                                          reviewUrl  ratingScore  \
# 0  B0BYJWRSC1  https://www.amazon.com/gp/customer-reviews/R6N...            4
# 1  B0BYJWRSC1  https://www.amazon.com/gp/customer-reviews/R39...            5
# 2  B0BYJWRSC1  https://www.amazon.com/gp/customer-reviews/R3V...            5
# 3  B0BT6W36HL  https://www.amazon.com/gp/customer-reviews/R2V...            5
# 4  B0BT6W36HL  https://www.amazon.com/gp/customer-reviews/R37...            5
#
#                                          reviewTitle  \
# 0                                     Painful Laptop
# 1                               Has all the features
# 2                                      Great Service
# 3  Lots of performance packed into a thin and lig...
# 4                                great AMOLED screen
#
#                                    reviewDescription        date  \
# 0  This is a fast and elegant looking Windows 11 ...  2023-05-06
# 1  This laptop is fast! 64 mb of ram really crank...  2023-04-20
# 2     Fast delivery and product exactly as described  2023-04-26
# 3  The Samsung 16" Galaxy Book3 Pro Business Lapt...  2023-05-06
# 4  I bought the Book3 Ultra version of this lapto...  2023-04-03
#
#                                      all_review_text  numPeopleFoundHelpful  \
# 0  Painful Laptop. This is a fast and elegant loo...                      1
# 1  Has all the features. This laptop is fast! 64 ...                      1
# 2  Great Service. Fast delivery and product exact...                      1
# 3  Lots of performance packed into a thin and lig...                      1
# 4  great AMOLED screen. I bought the Book3 Ultra ...                      6
#
#    wavgHelpfulness
# 0         0.333333
# 1         0.333333
# 2         0.333333
# 3         0.142857
# 4         0.857143

# %%
non_matchers = list(set(full_product_df.asin.unique()) - set(reviews_df.productAsin.unique())) + list(set(reviews_df.productAsin.unique()) - set(full_product_df.asin.unique()))
len(non_matchers)
# Out:
# 319

# %%
non_matchers = list(set(full_product_df.asin.unique()) - set(reviews_df.productAsin.unique())) + list(set(reviews_df.productAsin.unique()) - set(full_product_df.asin.unique()))
reviews_df = reviews_df[~reviews_df.productAsin.isin(non_matchers)]
full_product_df = full_product_df[~full_product_df.asin.isin(non_matchers)]
print(f'unique products in reviews_df: {reviews_df.productAsin.nunique()}')
print(f'unique products in product_df: {full_product_df.asin.nunique()}')
# Out:
# unique products in reviews_df: 1341
# unique products in product_df: 1341

# %%
# drop all rows containing null values
reviews_df = reviews_df.dropna()
full_product_df = full_product_df.dropna()
full_product_df.to_excel('./amazon_data/full_product_data.xlsx', index=False)
reviews_df.to_excel('./amazon_data/reviews_df.xlsx', index=False)
